# %% [markdown]
# # Casusopdracht Rode wijnen

# %% [markdown]
# #### Door Ricardo Tillemans, Berend Sliedrecht en Julian Buursink

# %% [markdown]
# ### Onderzoeksvragen

# %% [markdown]
# * In hoeverre is de score van een Portugese Red te voorspellen op basis van de chemische kenmerken?
# * Welke wijnen zullen een grotere prijs/kwaliteit genieten ten opzichte van de regio?
# * Welke tasters geven een hogere score voor wijnen met een hoger alcohol gehalte?

# %% [markdown]
# ### Eerste verkenning dataset

# %% [markdown]
# Hier worden alles geimporteerd en de instellingen klaar gezet, zodat de data makkelijk bekijkbaar is.

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import pandas as pd
import matplotlib.pyplot as plt
pd.set_option('display.max_rows', 25)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 100)

# %% [markdown]
# Hier openen we de geencodeerde csv om alle data handmatig over te gaan voor duplicaten en fouten.

# %%
wines =  pd.read_csv('redwineUTF.csv',sep=';')
wines
# Out:
#         id   country                                        description  \
# 0        1  Portugal  This is ripe and fruity, a wine that is smooth...
# 1        2  Portugal  From an estate in the south of the Alentejo, t...
# 2        3  Portugal  A year in wood and 30 months in bottle before ...
# 3        4  Portugal  Wood aging gives this ripe blend of Baga and T...
# 4        5  Portugal  A powerful wine, richly structured and full of...
# 5        6  Portugal  This is a new wine from the hands of master wi...
# 6        7  Portugal  As its name suggests this is a selection of ba...
# 7        8  Portugal  This is an impressive, powerful wine, It speak...
# 8        9  Portugal  Powerful and concentrated, this is just at its...
# 9       10  Portugal  This mature wine has a soft, smooth character ...
# 10      11  Portugal  A ripe and structured wine, this has bold blac...
# 11      12  Portugal  The latest release from the partnership betwee...
# ...

# %% [markdown]
# De grafieken die hier staan geven een mooie visualisatie van de data die in de tabel staat.

# %%
wines.iloc[1:100].plot(y='points');

# %%
wines.iloc[1:100].plot(y='price')

# %%
wines.iloc[1:100].plot(y='pH')
